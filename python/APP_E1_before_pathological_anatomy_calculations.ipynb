# %% [markdown]
# # Appendix E.1 Before pathological anatomy calculations, 1784 to 1822

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

from process_improvement import xmr_charts as xmr
from process_improvement import comparison_charts as cc

# %matplotlib inline

# %% [markdown]
# ## Step 1. Gather the data

# %%
# Get data
def get_data(dataset_url) -> pd.DataFrame:
    return pd.read_csv(dataset_url)

# Vienna url
vienna_url = r'https://raw.githubusercontent.com/jimlehner/the-virus-of-variation/refs/heads/main/data/pathological-anatomy-death-to-birth-rates.csv'

# Vienna General dataset url
vienna_df = get_data(vienna_url)

# Specifiy 'Year' column dtype as string
vienna_df['Year'] = vienna_df['Year'].astype('string')

# Show first 10 lines of vienna_df
vienna_df.columns
# Out:
# Index(['Hospital', 'Stage', 'Year', 'Births', 'Deaths', 'Rate', 'Note'], dtype='object')

# %% [markdown]
# ### Drop unnecessary columns from vienna_df

# %%
vienna_df = vienna_df[[#'Hospital', 
                       'Stage', 
                       #'Month', 
                       'Year', 
                       #'Births', 
                       #'Deaths',
                       'Rate']]
vienna_df
# Out:
#                           Stage  Year  Rate
# 0   Before pathological anatomy  1784   2.1
# 1   Before pathological anatomy  1785   1.4
# 2   Before pathological anatomy  1786   0.4
# 3   Before pathological anatomy  1787   0.4
# 4   Before pathological anatomy  1788   0.4
# 5   Before pathological anatomy  1789   0.6
# 6   Before pathological anatomy  1790   0.8
# 7   Before pathological anatomy  1791   0.6
# 8   Before pathological anatomy  1792   0.9
# 9   Before pathological anatomy  1793   2.6
# 10  Before pathological anatomy  1794   0.4
# 11  Before pathological anatomy  1795   2.1
# 12  Before pathological anatomy  1796   1.2
# 13  Before pathological anatomy  1797   0.2
# 14  Before pathological anatomy  1798   0.2
# 15  Before pathological anatomy  1799   1.0
# 16  Before pathological anatomy  1800   2.0
# 17  Before pathological anatomy  1801   0.8
# 18  Before pathological anatomy  1802   0.4
# 19  Before pathological anatomy  1803   0.7
# 20  Before pathological anatomy  1804   0.4
# 21  Before pathological anatomy  1805   0.4
# 22  Before pathological anatomy  1806   0.7
# 23  Before pathological anatomy  1807   0.6
# 24  Before pathological anatomy  1808   0.8
# 25  Before pathological anatomy  1809   1.4
# 26  Before pathological anatomy  1810   0.8
# 27  Before pathological anatomy  1811   1.9
# 28  Before pathological anatomy  1812   0.6
# 29  Before pathological anatomy  1813   1.1
# 30  Before pathological anatomy  1814   3.2
# 31  Before pathological anatomy  1815   0.7
# 32  Before pathological anatomy  1816   0.5
# 33  Before pathological anatomy  1817   0.9
# 34  Before pathological anatomy  1818   2.2
# 35  Before pathological anatomy  1819   5.0
# 36  Before pathological anatomy  1820   2.5
# 37  Before pathological anatomy  1821   1.7
# 38  Before pathological anatomy  1822   0.8
# 39   After pathological anatomy  1823   7.5
# 40   After pathological anatomy  1824   4.9
# 41   After pathological anatomy  1825   8.8
# 42   After pathological anatomy  1826   8.1
# 43   After pathological anatomy  1827   2.2
# 44   After pathological anatomy  1828   3.6
# 45   After pathological anatomy  1829   4.6
# 46   After pathological anatomy  1830   4.0
# 47   After pathological anatomy  1831   6.6
# 48   After pathological anatomy  1832   3.2
# 49   After pathological anatomy  1833   5.3
# 50   After pathological anatomy  1834   7.7
# 51   After pathological anatomy  1835   5.6
# 52   After pathological anatomy  1836   7.5
# 53   After pathological anatomy  1837   9.1
# 54   After pathological anatomy  1838   3.0
# 55   After pathological anatomy  1839   5.4
# 56   After pathological anatomy  1840   9.2

# %% [markdown]
# ### Split vienna_df into before_df and after_df

# %%
before_df = vienna_df[vienna_df['Stage'] == 'Before pathological anatomy'].copy()
after_df = vienna_df[vienna_df['Stage'] == 'After pathological anatomy'].reset_index(drop=True)

# %% [markdown]
# ## Step 2. Calculate the moving ranges

# %%
# Calculate the moving ranges for after_df
before_df['Moving Ranges'] = abs(before_df['Rate'].diff())
before_df
# Out:
#                           Stage  Year  Rate  Moving Ranges
# 0   Before pathological anatomy  1784   2.1            NaN
# 1   Before pathological anatomy  1785   1.4            0.7
# 2   Before pathological anatomy  1786   0.4            1.0
# 3   Before pathological anatomy  1787   0.4            0.0
# 4   Before pathological anatomy  1788   0.4            0.0
# 5   Before pathological anatomy  1789   0.6            0.2
# 6   Before pathological anatomy  1790   0.8            0.2
# 7   Before pathological anatomy  1791   0.6            0.2
# 8   Before pathological anatomy  1792   0.9            0.3
# 9   Before pathological anatomy  1793   2.6            1.7
# 10  Before pathological anatomy  1794   0.4            2.2
# 11  Before pathological anatomy  1795   2.1            1.7
# 12  Before pathological anatomy  1796   1.2            0.9
# 13  Before pathological anatomy  1797   0.2            1.0
# 14  Before pathological anatomy  1798   0.2            0.0
# 15  Before pathological anatomy  1799   1.0            0.8
# 16  Before pathological anatomy  1800   2.0            1.0
# 17  Before pathological anatomy  1801   0.8            1.2
# 18  Before pathological anatomy  1802   0.4            0.4
# 19  Before pathological anatomy  1803   0.7            0.3
# 20  Before pathological anatomy  1804   0.4            0.3
# 21  Before pathological anatomy  1805   0.4            0.0
# 22  Before pathological anatomy  1806   0.7            0.3
# 23  Before pathological anatomy  1807   0.6            0.1
# 24  Before pathological anatomy  1808   0.8            0.2
# 25  Before pathological anatomy  1809   1.4            0.6
# 26  Before pathological anatomy  1810   0.8            0.6
# 27  Before pathological anatomy  1811   1.9            1.1
# 28  Before pathological anatomy  1812   0.6            1.3
# 29  Before pathological anatomy  1813   1.1            0.5
# 30  Before pathological anatomy  1814   3.2            2.1
# 31  Before pathological anatomy  1815   0.7            2.5
# 32  Before pathological anatomy  1816   0.5            0.2
# 33  Before pathological anatomy  1817   0.9            0.4
# 34  Before pathological anatomy  1818   2.2            1.3
# 35  Before pathological anatomy  1819   5.0            2.8
# 36  Before pathological anatomy  1820   2.5            2.5
# 37  Before pathological anatomy  1821   1.7            0.8
# 38  Before pathological anatomy  1822   0.8            0.9

# %% [markdown]
# ## Step 3. Calculate the average moving range

# %%
# Calculate the average moving range for before_df['Moving Ranges']
before_ave_mR = round(before_df['Moving Ranges'].mean(),2)
before_ave_mR
# Out:
# 0.85

# %% [markdown]
# ## Step 4. Calculate the mean

# %%
# Calculate the mean before_df['Rate']
before_mean = round(before_df['Rate'].mean(),2)
before_mean
# Out:
# 1.16

# %% [markdown]
# ## Step 5. Calculate the process limits

# %%
# Upper Process Limit (UPL)
before_UPL = round(before_mean + (2.660*before_ave_mR),2)
# Lower Process Limit (LPL)
before_LPL = round(before_mean - (2.660*before_ave_mR),2)
before_LPL = max(0, before_LPL)
# Upper Process Limit (UPL)
before_URL = round(3.268*before_ave_mR,2)
# Show results
print('UPL', before_UPL)
print('LPL', before_LPL)
print('URL', before_URL)
# Out:
# UPL 3.42
# LPL 0
# URL 2.78

# %% [markdown]
# ## Step 6. Put it all together

# %%
before_results = xmr.xmr_chart(before_df,
                                'Rate',
                                'Year',
                                tickinterval=3, 
                                round_value=2, 
                                label_fontsize=14,
                                xtick_fontsize=12, 
                                xchart_ylabel='Death-to-Birth Rate (%)')
