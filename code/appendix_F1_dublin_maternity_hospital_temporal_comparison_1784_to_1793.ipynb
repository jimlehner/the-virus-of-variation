# %% [markdown]
# # Appendix F.1 Dublin Maternity Hospital Temporal Comparison Calculations - 1784 to 1793

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

from process_improvement import xmr_charts as xmr
from process_improvement import comparison_charts as cc

# %matplotlib inline

# %% [markdown]
# ## Step 1. Gather the data

# %%
# Get data
def get_data(dataset_url) -> pd.DataFrame:
    return pd.read_csv(dataset_url)

# Vienna url
temporal_url = r'https://raw.githubusercontent.com/jimlehner/the-virus-of-variation/refs/heads/main/data/temporal-comparison-death-to-birth-rates.csv'

# Get data
temporal_df = get_data(temporal_url)

# Show first 10 lines
temporal_df.head(10)

# Show columns
temporal_df.columns
# Out:
# Index(['Hospital', 'Stage', 'Year', 'Births', 'Deaths', 'Rate', 'Note'], dtype='object')

# %% [markdown]
# ### Drop  unnecessary columns from dataframe

# %%
temporal_df = temporal_df[['Hospital', 
                           'Stage', 
                           'Year', 
                           #'Births', 
                           #'Deaths', 
                           'Rate', 
                           #'Note' 
                          ]]

# Make 'Value' column dtype string
temporal_df['Year'] = temporal_df['Year'].astype('string').copy()

temporal_df
# Out:
#                      Hospital     Stage  Year  Rate
# 0     Vienna General Hospital  Period 1  1784   2.1
# 1     Vienna General Hospital  Period 1  1785   1.4
# 2     Vienna General Hospital  Period 1  1786   0.4
# 3     Vienna General Hospital  Period 1  1787   0.4
# 4     Vienna General Hospital  Period 1  1788   0.4
# 5     Vienna General Hospital  Period 1  1789   0.6
# 6     Vienna General Hospital  Period 1  1790   0.8
# 7     Vienna General Hospital  Period 1  1791   0.6
# 8     Vienna General Hospital  Period 1  1792   0.9
# 9     Vienna General Hospital  Period 1  1793   2.6
# 10    Vienna General Hospital  Period 2  1831   6.6
# 11    Vienna General Hospital  Period 2  1832   3.2
# 12    Vienna General Hospital  Period 2  1833   5.3
# 13    Vienna General Hospital  Period 2  1834   7.7
# 14    Vienna General Hospital  Period 2  1835   5.6
# 15    Vienna General Hospital  Period 2  1836   7.5
# 16    Vienna General Hospital  Period 2  1837   9.1
# 17    Vienna General Hospital  Period 2  1838   3.0
# 18    Vienna General Hospital  Period 2  1839   5.4
# 19    Vienna General Hospital  Period 2  1840   9.2
# 20  Dublin Maternity Hospital  Period 1  1784   0.9
# 21  Dublin Maternity Hospital  Period 1  1785   0.6
# 22  Dublin Maternity Hospital  Period 1  1786   0.6
# 23  Dublin Maternity Hospital  Period 1  1787   0.7
# 24  Dublin Maternity Hospital  Period 1  1788   1.6
# 25  Dublin Maternity Hospital  Period 1  1789   1.7
# 26  Dublin Maternity Hospital  Period 1  1790   0.8
# 27  Dublin Maternity Hospital  Period 1  1791   1.6
# 28  Dublin Maternity Hospital  Period 1  1792   0.6
# 29  Dublin Maternity Hospital  Period 1  1793   1.1
# 30  Dublin Maternity Hospital  Period 2  1831   0.6
# 31  Dublin Maternity Hospital  Period 2  1832   0.5
# 32  Dublin Maternity Hospital  Period 2  1833   0.6
# 33  Dublin Maternity Hospital  Period 2  1834   1.7
# 34  Dublin Maternity Hospital  Period 2  1835   1.8
# 35  Dublin Maternity Hospital  Period 2  1836   2.0
# 36  Dublin Maternity Hospital  Period 2  1837   1.3
# 37  Dublin Maternity Hospital  Period 2  1838   2.1
# 38  Dublin Maternity Hospital  Period 2  1839   1.3
# 39  Dublin Maternity Hospital  Period 2  1840   1.7

# %% [markdown]
# ### Splite dataframe according to stage

# %%
# Create dataframe for 1784 to 1793
Dublin_P1_df = temporal_df[(temporal_df['Hospital'] == 'Dublin Maternity Hospital') & (temporal_df['Stage'] == 'Period 1')].reset_index(drop=True).copy()
# Create dataframe for 1831 to 1840
Dublin_P2_df = temporal_df[(temporal_df['Hospital'] == 'Dublin Maternity Hospital') & (temporal_df['Stage'] == 'Period 2')].reset_index(drop=True).copy()

# %% [markdown]
# ## Step 2. Calculate the moving ranges for Dublin period 1 (1784 to 1793)

# %%
# Calculate the moving ranges for before_df
Dublin_P1_df['Moving Ranges'] = abs(Dublin_P1_df['Rate'].diff())
Dublin_P1_df
# Out:
#                     Hospital     Stage  Year  Rate  Moving Ranges
# 0  Dublin Maternity Hospital  Period 1  1784   0.9            NaN
# 1  Dublin Maternity Hospital  Period 1  1785   0.6            0.3
# 2  Dublin Maternity Hospital  Period 1  1786   0.6            0.0
# 3  Dublin Maternity Hospital  Period 1  1787   0.7            0.1
# 4  Dublin Maternity Hospital  Period 1  1788   1.6            0.9
# 5  Dublin Maternity Hospital  Period 1  1789   1.7            0.1
# 6  Dublin Maternity Hospital  Period 1  1790   0.8            0.9
# 7  Dublin Maternity Hospital  Period 1  1791   1.6            0.8
# 8  Dublin Maternity Hospital  Period 1  1792   0.6            1.0
# 9  Dublin Maternity Hospital  Period 1  1793   1.1            0.5

# %% [markdown]
# ## Step 3. Calculate the average moving range

# %%
# Calculate the average moving range for before_df['Moving Ranges']
Dublin_ave_mR = round(Dublin_P1_df['Moving Ranges'].mean(),2)
Dublin_ave_mR
# Out:
# 0.51

# %% [markdown]
# ## Step 4. Calculate the mean

# %%
# Calculate the mean before_df['Rate']
Dublin_mean = round(Dublin_P1_df['Rate'].mean(),2)
Dublin_mean
# Out:
# 1.02

# %% [markdown]
# ## Step 5. Calculate the process limits

# %%
# Upper Process Limit (UPL)
Dublin_UPL = round(Dublin_mean + (2.660*Dublin_ave_mR),2)
# Lower Process Limit (LPL)
Dublin_LPL_calc = round(Dublin_mean - (2.660*Dublin_ave_mR),2)
# Ensure that LPL is not negative
Dublin_LPL = max(0, Dublin_LPL_calc)
# Upper Process Limit (UPL)
Dublin_URL = round(3.268*Dublin_ave_mR,2)
# Show results
print('UPL:', Dublin_UPL)
print('Calculated LPL:', Dublin_LPL_calc)
print('LPL:', Dublin_LPL)
print('URL:', Dublin_URL)
# Out:
# UPL: 2.38
# Calculated LPL: -0.34
# LPL: 0
# URL: 1.67

# %% [markdown]
# ## Step 6. Put it all together

# %%
Dublin_results = xmr.xmr_chart(Dublin_P1_df,
                                'Rate',
                                'Year',
                                tickinterval=1, 
                                round_value=2, 
                                label_fontsize=14,
                                xtick_fontsize=12)
