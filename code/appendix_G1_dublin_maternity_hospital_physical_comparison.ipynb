# %% [markdown]
# # Appendix G.1 Dublin Maternity Hospital physical comparison calculations

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

from process_improvement import xmr_charts as xmr
from process_improvement import comparison_charts as cc

# %matplotlib inline

# %% [markdown]
# ## Step 1. Gather the data

# %%
# Get data
def get_data(dataset_url) -> pd.DataFrame:
    return pd.read_csv(dataset_url)

# Vienna url
rates_url = r'https://raw.githubusercontent.com/jimlehner/the-virus-of-variation/refs/heads/main/data/physical-comparison-death-to-birth-rates.csv'
# Vienna General dataset url
rates_df = get_data(rates_url)

# Show first 10 lines of rates_df
rates_df.head(10)

# Show columns
rates_df.columns
# Out:
# Index(['Hospital', 'Year', 'Births', 'Deaths', 'Rate', 'Note'], dtype='object')

# %% [markdown]
# ### Drop  unnecessary columns from dataframe

# %%
rates_df = rates_df[['Hospital', 
           'Year', 
           #'Births', 
           #'Deaths', 
           'Rate', 
           #'Note'
          ]]

# Make 'Year' column dtype string
rates_df['Year'] = rates_df['Year'].astype('string')

# Show dataframe dtypes
rates_df.dtypes
# Out:
# Hospital     object
# Year         string
# Rate        float64
# dtype: object

# %% [markdown]
# ### Splite dataframe according to stage

# %%
dublin_df = rates_df[rates_df['Hospital'] == 'Dublin Maternity Hospital'].copy().reset_index(drop=True)
vienna_df = rates_df[rates_df['Hospital'] == 'Vienna General Hospital'].reset_index(drop=True)

# %% [markdown]
# ## Step 2. Calculate the moving ranges

# %%
# Calculate the moving ranges for before_df
dublin_df['Moving Ranges'] = abs(dublin_df['Rate'].diff())
dublin_df
# Out:
#                      Hospital  Year  Rate  Moving Ranges
# 0   Dublin Maternity Hospital  1784   0.9            NaN
# 1   Dublin Maternity Hospital  1785   0.6            0.3
# 2   Dublin Maternity Hospital  1786   0.6            0.0
# 3   Dublin Maternity Hospital  1787   0.7            0.1
# 4   Dublin Maternity Hospital  1788   1.6            0.9
# 5   Dublin Maternity Hospital  1789   1.7            0.1
# 6   Dublin Maternity Hospital  1790   0.8            0.9
# 7   Dublin Maternity Hospital  1791   1.6            0.8
# 8   Dublin Maternity Hospital  1792   0.6            1.0
# 9   Dublin Maternity Hospital  1793   1.1            0.5
# 10  Dublin Maternity Hospital  1794   1.3            0.2
# 11  Dublin Maternity Hospital  1795   0.5            0.8
# 12  Dublin Maternity Hospital  1796   0.6            0.1
# 13  Dublin Maternity Hospital  1797   0.8            0.2
# 14  Dublin Maternity Hospital  1798   0.5            0.3
# 15  Dublin Maternity Hospital  1799   0.7            0.2
# 16  Dublin Maternity Hospital  1800   1.0            0.3
# 17  Dublin Maternity Hospital  1801   1.7            0.7
# 18  Dublin Maternity Hospital  1802   1.3            0.4
# 19  Dublin Maternity Hospital  1803   2.2            0.9
# 20  Dublin Maternity Hospital  1804   0.8            1.4
# 21  Dublin Maternity Hospital  1805   0.5            0.3
# 22  Dublin Maternity Hospital  1806   1.0            0.5
# 23  Dublin Maternity Hospital  1807   0.5            0.5
# 24  Dublin Maternity Hospital  1808   0.5            0.0
# 25  Dublin Maternity Hospital  1809   0.7            0.2
# 26  Dublin Maternity Hospital  1810   1.0            0.3
# 27  Dublin Maternity Hospital  1811   0.9            0.1
# 28  Dublin Maternity Hospital  1812   1.6            0.7
# 29  Dublin Maternity Hospital  1813   2.5            0.9
# 30  Dublin Maternity Hospital  1814   1.0            1.5
# 31  Dublin Maternity Hospital  1815   0.6            0.4
# 32  Dublin Maternity Hospital  1816   0.5            0.1
# 33  Dublin Maternity Hospital  1817   0.9            0.4
# 34  Dublin Maternity Hospital  1818   1.6            0.7
# 35  Dublin Maternity Hospital  1819   2.9            1.3
# 36  Dublin Maternity Hospital  1820   2.8            0.1
# 37  Dublin Maternity Hospital  1821   0.8            2.0
# 38  Dublin Maternity Hospital  1822   0.4            0.4
# 39  Dublin Maternity Hospital  1823   2.3            1.9
# 40  Dublin Maternity Hospital  1824   0.8            1.5
# 41  Dublin Maternity Hospital  1825   0.9            0.1
# 42  Dublin Maternity Hospital  1826   3.3            2.4
# 43  Dublin Maternity Hospital  1827   1.3            2.0
# 44  Dublin Maternity Hospital  1828   1.5            0.2
# 45  Dublin Maternity Hospital  1829   1.6            0.1
# 46  Dublin Maternity Hospital  1830   0.5            1.1
# 47  Dublin Maternity Hospital  1831   0.6            0.1
# 48  Dublin Maternity Hospital  1832   0.5            0.1
# 49  Dublin Maternity Hospital  1833   0.6            0.1
# 50  Dublin Maternity Hospital  1834   1.7            1.1
# 51  Dublin Maternity Hospital  1835   1.8            0.1
# 52  Dublin Maternity Hospital  1836   2.0            0.2
# 53  Dublin Maternity Hospital  1837   1.3            0.7
# 54  Dublin Maternity Hospital  1838   2.1            0.8
# 55  Dublin Maternity Hospital  1839   1.3            0.8
# 56  Dublin Maternity Hospital  1840   1.7            0.4

# %% [markdown]
# ## Step 3. Calculate the average moving range

# %%
# Calculate the average moving range for before_df['Moving Ranges']
dublin_ave_mR = round(dublin_df['Moving Ranges'].mean(),2)
dublin_ave_mR
# Out:
# 0.61

# %% [markdown]
# ## Step 4. Calculate the mean

# %%
# Calculate the mean before_df['Rate']
dublin_mean = round(dublin_df['Rate'].mean(),2)
dublin_mean
# Out:
# 1.19

# %% [markdown]
# ## Step 5. Calculate the process limits

# %%
# Upper Process Limit (UPL)
dublin_UPL = round(dublin_mean + (2.660*dublin_ave_mR),2)
# Lower Process Limit (LPL)
dublin_LPL = round(dublin_mean - (2.660*dublin_ave_mR),2)
# Upper Process Limit (UPL)
dublin_URL = round(3.268*dublin_ave_mR,2)
# Show results
print('UPL:', dublin_UPL)
print('LPL:', dublin_LPL)
print('URL:', dublin_URL)
# Out:
# UPL: 2.81
# LPL: -0.43
# URL: 1.99

# %% [markdown]
# ## Step 6. Put it all together

# %%
dublin_results = xmr.xmr_chart(dublin_df,
                                'Rate',
                                'Year',
                                tickinterval=4, 
                                round_value=2, 
                                label_fontsize=14,
                                xtick_fontsize=12)
